# %%
i = 0
while i >= i:
  try:
    number = int(input("Please enter a number between 1-20 : "))
    number1 = str(number)
    numbers = []
    numbers2 = []
    AsBackEven = str(ord('N')) + str(ord('E')) + str(ord('V')) + str(ord('E'))
    AsBackOdd = str(ord('D')) + str(ord('D')) + str(ord('O'))
    Even = 'Even'
    NEVE = 'NEVE'
    Odd = 'Odd'
    DDO = 'DDO'

    # 1 digit number
    if number >= 1 and number <= 9 :

      #even number
      if number%2 == 0 :
        numbers.append(Even + str(number))
        numbers.append(NEVE + str(number))
        numbers.append(AsBackEven + str(number))
        numbers.append(NEVE + str(number))
        numbers.append(Even + str(number))
        numbers.append(number)

      #odd number
      else:
        numbers.append(Odd + str(number))

        numbers.append(DDO + str(number))
        numbers.append(AsBackOdd + str(number))
        numbers.append(DDO + str(number))
        numbers.append(Odd + str(number))
        numbers.append(number)

      #result 2 digit number
      print("Function A : " + numbers[0])
      print("Function B : " + numbers[1])
      print("Function C : " + numbers[2])
      print("Function D : " + numbers[3])
      print("Function E : " + numbers[4])
      print("Function F : " + str(numbers[5]))

    # 2 digit number
    elif number >= 10 and number <= 20 :
      n = 0
      len(number1)
      while n < 2:
        if n == 0 :

          #even number
          if int(number1[0])%2 == 0 :
            numbers.append(Even + str(number1[0]))
            numbers.append(NEVE + str(number1[0]))
            numbers.append(AsBackEven + str(number1[0]))
            numbers.append(NEVE + str(number1[0]))
            numbers.append(Even + str(number1[0]))
            numbers.append(str(number1[0]))

          #odd number
          else :
            numbers.append(Odd + str(number1[0]))
            numbers.append(DDO + str(number1[0]))
            numbers.append(AsBackOdd + str(number1[0]))
            numbers.append(DDO + str(number1[0]))
            numbers.append(Odd + str(number1[0]))
            numbers.append(str(number1[0]))  
        else :

          #even number
          if int(number1[1])%2 == 0 :
            numbers2.append(Even + str(number1[1])) 
            numbers2.append(NEVE + str(number1[1]))
            numbers2.append(AsBackEven + str(number1[1]))
            numbers2.append(NEVE + str(number1[1]))
            numbers2.append(Even + str(number1[1]))
            numbers2.append(str(number1[1]))

          #odd number
          else:
            numbers2.append(Odd + str(number1[1]))  
            numbers2.append(DDO + str(number1[1]))
            numbers2.append(AsBackOdd + str(number1[1]))
            numbers2.append(DDO + str(number1[1]))
            numbers2.append(Odd + str(number1[1]))
            numbers2.append(str(number1[1]))
        
        n=n+1

      #result 2 digit number
      print("Function A : " + numbers[0] + numbers2[0])
      print("Function B : " + numbers[1] + numbers2[1])
      print("Function C : " + numbers[2] + numbers2[2])
      print("Function D : " + numbers[3] + numbers2[3])
      print("Function E : " + numbers[4] + numbers2[4])
      print("Function F : " + str(numbers[5]) + str(numbers2[5]))


    else :
      print("Please enter a number 1-20")

  except:
    print("Please enter a number")

#Function A numbers[0]
#Function B numbers[1]
#Function C numbers[2]
#Function D numbers[3]
#Function E numbers[4]
#Function F numbers[5]
